# %%
import seaborn as sns
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
data = pd.read_excel('Dataset/Salaries.xlsx')
pd. __version__
# Out:
# '1.5.1'

# %%
#data.head()

# %% [markdown]
# Get dummies

# %%
experience_dum = pd.get_dummies(data.Experience)
title_dum = pd.get_dummies(data.Title)
com_loc_dum = pd.get_dummies(data['Company location']).drop("AE",axis=1)

merged = pd.concat([data.Year, title_dum], axis=1)

merged
# Out:
#      Year  3D Computer Vision Researcher  AI Scientist  Analytics Engineer  \
# 0    2020                              0             0                   0
# 1    2020                              0             0                   0
# 2    2020                              0             0                   0
# 3    2020                              0             0                   0
# 4    2020                              0             0                   0
# ..    ...                            ...           ...                 ...
# 602  2022                              0             0                   0
# 603  2022                              0             0                   0
# 604  2022                              0             0                   0
# 605  2022                              0             0                   0
# 606  2022                              0             1                   0
#
#      Applied Data Scientist  Applied Machine Learning Scientist  \
# ...

# %%
x = merged.drop(['Year'], axis=1)
y = data['Salary in USD']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)

# %%
x
# Out:
#      3D Computer Vision Researcher  AI Scientist  Analytics Engineer  \
# 0                                0             0                   0
# 1                                0             0                   0
# 2                                0             0                   0
# 3                                0             0                   0
# 4                                0             0                   0
# ..                             ...           ...                 ...
# 602                              0             0                   0
# 603                              0             0                   0
# 604                              0             0                   0
# 605                              0             0                   0
# 606                              0             1                   0
#
#      Applied Data Scientist  Applied Machine Learning Scientist  \
# 0                         0                                   0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
predicted = lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, predicted)
# Out:
# 55523.451692320545

# %%
predicted
# Out:
# array([113381.22689076,  69508.83333333,  94229.98611111, 110493.56880734,
#        188487.2       , 113381.22689076, 110493.56880734, 110493.56880734,
#         97586.89285714, 110493.56880734,  94229.98611111, 150203.25      ,
#        113381.22689076, 113381.22689076,  83705.        , 110493.56880734,
#         94229.98611111, 110493.56880734, 110493.56880734, 110493.56880734,
#        113381.22689076,  94229.98611111, 110493.56880734,  97586.89285714,
#         69367.33333333,  97586.89285714, 113381.22689076,  94229.98611111,
#         97586.89285714, 113381.22689076, 110493.56880734,  89395.5       ,
#         97586.89285714, 113381.22689076,  94229.98611111,  94229.98611111,
#         94229.98611111,  94229.98611111, 110493.56880734, 110493.56880734,
#        110493.56880734, 117431.69230769,  94229.98611111,  94229.98611111,
#         94229.98611111, 110493.56880734,  94229.98611111, 180801.625     ,
# ...

# %%
result = pd.concat([y_test, predicted], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [303], in <cell line: 1>()
# ----> 1 result = pd.concat([y_test, predicted], axis=1)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
# ...

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [304], in <cell line: 1>()
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
# Out:
# 3797823596326909.5

# %%
currency_dum = pd.get_dummies(data.Currency).drop("JPY", axis=1)
title_dum = pd.get_dummies(data.Title).drop("Staff Data Scientist", axis=1)
type_dum = pd.get_dummies(data.Type).drop("Temporary", axis=1)
experience_dum = pd.get_dummies(data.Experience).drop("Senior", axis=1)
residence_dummy = pd.get_dummies(data.Residence).drop("AE",axis=1)
remote_work_dum = pd.get_dummies(data['Remote work']).drop("Yes", axis=1)
com_loc_dum = pd.get_dummies(data['Company location']).drop("AE",axis=1)
com_size_dum = pd.get_dummies(data['Company size']).drop("S",axis=1)
merged = pd.concat([data,currency_dum,title_dum,type_dum,experience_dum,residence_dummy,remote_work_dum,com_loc_dum,com_size_dum], axis=1)
merged = merged.drop(['Experience', 'Type', 'Title', 'Residence', 'Salary',
       'Currency', 'Remote work', 'Company location', 'Company size'], axis=1)

# %%
currency_dum = pd.get_dummies(data.Currency)
title_dum = pd.get_dummies(data.Title)
type_dum = pd.get_dummies(data.Type)
experience_dum = pd.get_dummies(data.Experience)
residence_dummy = pd.get_dummies(data.Residence)
remote_work_dum = pd.get_dummies(data['Remote work'])
com_loc_dum = pd.get_dummies(data['Company location'])
com_size_dum = pd.get_dummies(data['Company size'])
merged = pd.concat([data,currency_dum,title_dum,type_dum,experience_dum,residence_dummy,remote_work_dum,com_loc_dum,com_size_dum], axis=1)
merged = merged.drop(['Experience', 'Type', 'Title', 'Residence', 'Salary',
       'Currency', 'Remote work', 'Company location', 'Company size', 'Year'], axis=1)
merged

# %%
sns.distplot(data['Salary in USD'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary in USD', ylabel='Density'>

# %%
sns.jointplot(x='Year',y='Salary in USD',data=data,kind='reg')

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#    Year    Experience       Type                       Title Residence  \
# 0  2020  Intermediate  Full-time              Data Scientist        DE
# 1  2020        Senior  Full-time  Machine Learning Scientist        JP
# 2  2020        Senior  Full-time           Big Data Engineer        GB
# 3  2020  Intermediate  Full-time        Product Data Analyst        HN
# 4  2020        Senior  Full-time   Machine Learning Engineer        US
#
#    Salary Currency Remote work Company location Company size  Salary in USD
# 0   70000      EUR          No               DE            L          79833
# 1  260000      USD          No               JP            S         260000
# 2   85000      GBP   Partially               GB            M         109024
# 3   20000      USD          No               HN            S          20000
# 4  150000      USD   Partially               US            L         150000

# %%
#sns.pairplot(data,hue='Title',palette='coolwarm')

# %%
#sns.barplot(y='Salary in USD',x='Experience',data=data, hue="Remote work")

# %%
#sns.barplot(x='Company size',y='Salary in USD',data=data)

# %%
titlesList = data['Title'].unique()

# %%
#data.pivot_table(index="Title", columns="Year", values="Salary in USD")

# %%
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#data.describe()
#data.columns
# Out:
# Index(['Year', 'Experience', 'Type', 'Title', 'Residence', 'Salary',
#        'Currency', 'Remote work', 'Company location', 'Company size',
#        'Salary in USD'],
#       dtype='object')
